# %% [markdown]
# <a href="https://colab.research.google.com/github/EarelJohnOnod/CPE009A-OOP/blob/main/Prelim_Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROGRAM**

# %%
n = 20
tn = n
sum = 0
ave = 0

while(n>=0):
  sum += n
  n -= 1
else:
  ave = sum / tn
  print(ave)
# Out:
# 10.5

# %% [markdown]
# **DIAGRAM**

# %% [markdown]
# ![Prelim Quiz (Diagram).png](data:image/png;base64,...)
